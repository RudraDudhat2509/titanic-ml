# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('train.csv')
df1=pd.read_csv('test.csv')

# %%
Passenger_id=df1['PassengerId']

# %%
df=pd.concat([df,df1],axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df['Fare']=df['Fare'].fillna(df['Fare'].median())

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived     418
# Pclass         0
# Sex            0
# Age          263
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin       1014
# Embarked       2
# dtype: int64

# %%
df.loc[:,'Age']=df['Age'].fillna(df['Age'].median())

# %%
df['TotalRel']=df['SibSp']+df['Parch']
df.drop(columns=['SibSp','Parch','Ticket'],axis=1,inplace=True)

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    418
# Pclass        0
# Sex           0
# Age           0
# Fare          0
# Embarked      2
# TotalRel      0
# dtype: int64

# %%
df['Sex']=df['Sex'].replace(['male','female'],[0,1])
# Out:
# C:\Users\rocki\AppData\Local\Temp\ipykernel_17540\1450664526.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex']=df['Sex'].replace(['male','female'],[0,1])

# %%
from sklearn.preprocessing import LabelEncoder
lbe=LabelEncoder()

# %%
df.loc[:,'Embarked']=lbe.fit_transform(df['Embarked'])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare Embarked  TotalRel
# 0       0.0       3    0  22.0   7.2500        2         1
# 1       1.0       1    1  38.0  71.2833        0         1
# 2       1.0       3    1  26.0   7.9250        2         0
# 3       1.0       1    1  35.0  53.1000        2         1
# 4       0.0       3    0  35.0   8.0500        2         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Sex       1309 non-null   int64
#  3   Age       1309 non-null   float64
#  4   Fare      1309 non-null   float64
#  5   Embarked  1309 non-null   object
#  6   TotalRel  1309 non-null   int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 81.8+ KB

# %%
df['Embarked']=df['Embarked'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Sex       1309 non-null   int64
#  3   Age       1309 non-null   float64
#  4   Fare      1309 non-null   float64
#  5   Embarked  1309 non-null   int64
#  6   TotalRel  1309 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 81.8 KB

# %%
train=df.iloc[0:891,:]
test=df.iloc[891:,:]

# %%
train.shape, test.shape
# Out:
# ((891, 7), (418, 7))

# %%
train.tail()
# Out:
#      Survived  Pclass  Sex   Age   Fare  Embarked  TotalRel
# 886       0.0       2    0  27.0  13.00         2         0
# 887       1.0       1    1  19.0  30.00         2         0
# 888       0.0       3    1  28.0  23.45         2         3
# 889       1.0       1    0  26.0  30.00         0         0
# 890       0.0       3    0  32.0   7.75         1         0

# %%
test.isnull().sum()
# Out:
# Survived    418
# Pclass        0
# Sex           0
# Age           0
# Fare          0
# Embarked      0
# TotalRel      0
# dtype: int64

# %%
Y_train=train['Survived']
X_train=train.drop('Survived',axis=1)
X_train.shape,Y_train.shape
# Out:
# ((891, 6), (891,))

# %%
X_test=test.drop('Survived',axis=1)

# %%
X_test.shape
# Out:
# (418, 6)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
model1=RandomForestClassifier()
model2=LogisticRegression(n_jobs=-1)

# %%
model2.fit(X_train,Y_train)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
model=RandomForestClassifier(class_weight='balanced')

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred=model2.predict(X_test)

# %%
final=pd.DataFrame(
{
    'PassengerId':Passenger_id,
    'Survived':y_pred
})

# %%
final.to_csv('gender_submission2.csv',index=False)

# %%
y_pred.sum()
# Out:
# np.float64(154.0)
